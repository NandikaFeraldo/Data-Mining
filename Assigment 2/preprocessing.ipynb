# %% [markdown]
# Import Library yang digunakan

# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd

# %% [markdown]
# Import datasets

# %%
dataset = pd.read_csv('Data.csv')
x = dataset.iloc[:, 0:4].values
y = dataset.iloc[:, -1].values

# %%
print(x)
# Out:
# [['Country;Year;Both sexs;Male;Female;Both sexs;Male;Female' nan nan nan]
#  ['Afghanistan;2019;35.3 [21.8-49.8];34.4 [21.9-47.9];36.2 [21.7-51.6];4.1 [2.3-7.0];4.6 [2.6-7.9];3.6 [2.0-5.9]'
#   nan nan nan]
#  ['Afghanistan;2018;35.4 [21.7-50.1];34.7 [22.0-48.5];36.0 [21.4-51.6];4.1 [2.3-6.8];4.6 [2.6-7.8];3.5 [2.0-5.8]'
#   nan nan nan]
#  ...
#  ['Zimbabwe;2002;22.7 [14.4-32.9];24.1 [16.3-33.9];21.5 [13.0-32.0];13.4 [7.0-21.6];15.5 [8.3-23.6];11.4 [5.7-19.7]'
#   nan nan nan]
#  ['Zimbabwe;2001;21.7 [13.8-31.6];23.6 [16.0-33.2];20.2 [12.1-30.4];12.8 [6.6-20.9];14.4 [7.7-22.0];11.3 [5.4-19.8]'
#   nan nan nan]
#  ['Zimbabwe;2000;21.4 [13.6-31.2];23.3 [15.9-32.8];19.8 [11.7-29.9];13.3 [6.7-21.7];14.1 [7.5-21.5];12.4 [5.9-21.9]'
#   nan nan nan]]

# %%
print(y)

# %% [markdown]
# Menghilangkan missing value (nan)

# %%
from sklearn.impute import SimpleImputer
imputer = Simpleimputer(missing_value=np.nan, strategy ='mean')
imputer.fit(x[:, 1:3])
X[:, 1:3] = imputer.transform(X[:, 1:3])

# %%
print(x)

# %% [markdown]
# Encoding data kategori (atribut)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = Columnformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
print(x)

# %% [markdown]
# Encoding data kategori (class/label)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
print(y)

# %% [markdown]
# Membagi dataset ke dalam teraining set dan tes set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_test = train_test_split(x, y, test_size = 0,2, random_state = 1)

# %%
print(X_test)

# %%
print(y_train)

# %%
print(y_test)

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandarScaler()
X_train[:, 3:] = sc.fit_transform(X_train[:, 3:])
X_test[:, 3:] = sc.transform(X_test[:, 3:])

# %%
print(X_train)

# %%
print(X_test)
